# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/panicpotatoe/dataset-practical-stats/main/ds_salaries.csv")
df.sample(10)
# Out:
#       work_year experience_level employment_type                  job_title  \
# 164        2023               SE              FT          Applied Scientist
# 2182       2022               SE              FT               Data Analyst
# 2498       2022               SE              FT  Machine Learning Engineer
# 506        2023               SE              FT  Machine Learning Engineer
# 2529       2022               SE              FT             Data Architect
# 3347       2022               MI              FT             Data Scientist
# 59         2023               EX              FT             Data Scientist
# 2434       2022               MI              FT  Machine Learning Engineer
# 395        2023               EN              FT              Data Engineer
# 2507       2022               SE              FT              Data Engineer
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
df.astype('object').describe()
# Out:
#         work_year experience_level employment_type      job_title  salary  \
# count        3755             3755            3755           3755    3755
# unique          4                4               4             93     815
# top          2023               SE              FT  Data Engineer  100000
# freq         1785             2516            3718           1040     112
#
#        salary_currency  salary_in_usd employee_residence  remote_ratio  \
# count             3755           3755               3755          3755
# unique              20           1035                 78             3
# top                USD         100000                 US             0
# freq              3224             99               3004          1923
#
#        company_location company_size
# count              3755         3755
# unique               72            3
# top                  US            M
# freq               3040         3153

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %% [markdown]
# ### Visualize and describe the feature you most concern

# %%
df.pivot_table(index='job_title').assign(total_job_title=len(df.loc['job_title']))
# Out:
# C:\Users\phucd\AppData\Local\Temp\ipykernel_14636\3131141052.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df.pivot_table(index='job_title').assign(total_job_title=len(df.loc['job_title']))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.pivot_table(index='job_title').assign(total_job_title=len(df.loc['job_title']))
#
# File s:\learning-projects\ml\aptech_s3\.venv\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %% [markdown]
# ### Q3: Get the top 20 most popular jobs title

# %%
df[['job_title','work_year']].pivot_table(index='job_title', aggfunc='count').sort_values('work_year', ascending=False).head(20)
# Out:
#                             work_year
# job_title
# Data Engineer                    1040
# Data Scientist                    840
# Data Analyst                      612
# Machine Learning Engineer         289
# Analytics Engineer                103
# Data Architect                    101
# Research Scientist                 82
# Data Science Manager               58
# Applied Scientist                  58
# Research Engineer                  37
# ML Engineer                        34
# Data Manager                       29
# Machine Learning Scientist         26
# Data Science Consultant            24
# Data Analytics Manager             22
# Computer Vision Engineer           18
# AI Scientist                       16
# BI Data Analyst                    15
# Business Data Analyst              15
# Data Specialist                    14

# %%
# giả định tương lai
df_2023 = df[df['work_year'] == 2023].reset_index()
df_2023.sample(10)
# Out:
#       index  work_year experience_level employment_type  \
# 772     783       2023               SE              FT
# 1300   1319       2023               MI              FT
# 1273   1292       2023               SE              FT
# 846     857       2023               EN              FT
# 1279   1298       2023               SE              FT
# 354     360       2023               MI              FT
# 665     674       2023               MI              FT
# 1059   1075       2023               SE              FT
# 900     911       2023               SE              FT
# 1150   1167       2023               SE              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 772   Machine Learning Engineer  247500             USD         247500
# 1300  Machine Learning Engineer  120000             GBP         145828
# 1273             Data Scientist  145000             USD         145000
# ...

# %%
# chọn bộ quá khứ
df_old = df[df['work_year'] != 2023].reset_index()
df_old.sample(10)
# Out:
#       index  work_year experience_level employment_type  \
# 704    2489       2022               SE              FT
# 1526   3311       2022               EX              FT
# 472    2257       2022               MI              FT
# 737    2522       2022               EX              FT
# 907    2692       2022               SE              FT
# 31     1746       2022               EN              FT
# 1417   3202       2022               MI              FT
# 1670   3455       2020               MI              FT
# 1332   3117       2022               EN              FT
# 1027   2812       2022               SE              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 704                Data Analyst   52500             USD          52500
# 1526       Head of Data Science  167875             USD         167875
# 472          Analytics Engineer   85000             GBP         104663
# ...
