# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/panicpotatoe/dataset-practical-stats/main/state.csv')
df.sample(5)
# Out:
#             State  Population  Murder.Rate Abbreviation
# 8         Florida    18801310          5.8           FL
# 26       Nebraska     1826341          2.9           NE
# 43           Utah     2763885          2.3           UT
# 31       New York    19378102          3.1           NY
# 47  West Virginia     1852994          4.0           WV

# %%
import seaborn as sns

# %%
sns.histplot(data=df, x='Population', bins=50)
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.boxplot(data=df['Population'])
# Out:
# <Axes: >

# %%
sns.histplot(data=df, x='Murder.Rate', bins=50)
# Out:
# <Axes: xlabel='Murder.Rate', ylabel='Count'>

# %%
sns.boxplot(data=df['Murder.Rate'])
# Out:
# <Axes: >
