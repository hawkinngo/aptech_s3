# %%
import numpy as np

# %%
def CoinThrowing():
    throwing = np.random.randint(0,2)
    return "Up" if throwing > 0 else "Down"

def ThrowCoin(times):
    total_throwing = [CoinThrowing() for i in range(times)]
    print(total_throwing)
    sns.histplot(data=total_throwing)

# %%
import seaborn as sns

# %%
ThrowCoin(100)
ThrowCoin(100)
ThrowCoin(100)
# Out:
# ['Down', 'Down', 'Down', 'Down', 'Down', 'Up', 'Up', 'Up', 'Up', 'Down', 'Up', 'Down', 'Down', 'Up', 'Up', 'Down', 'Down', 'Down', 'Up', 'Up', 'Down', 'Up', 'Up', 'Down', 'Up', 'Down', 'Up', 'Down', 'Up', 'Up', 'Down', 'Down', 'Up', 'Down', 'Up', 'Up', 'Up', 'Down', 'Down', 'Down', 'Down', 'Up', 'Up', 'Up', 'Up', 'Up', 'Up', 'Up', 'Down', 'Up', 'Up', 'Down', 'Up', 'Up', 'Up', 'Down', 'Up', 'Up', 'Up', 'Down', 'Down', 'Down', 'Up', 'Down', 'Up', 'Up', 'Up', 'Up', 'Down', 'Down', 'Down', 'Down', 'Up', 'Down', 'Down', 'Up', 'Down', 'Down', 'Down', 'Down', 'Up', 'Down', 'Up', 'Down', 'Down', 'Down', 'Up', 'Up', 'Down', 'Down', 'Up', 'Up', 'Down', 'Up', 'Up', 'Up', 'Down', 'Up', 'Down', 'Up']
# ...

# %%
def DiceThrowing():
    throwing = np.random.randint(1,7)
    return throwing
    
def ThrowDice(times):
    total_throwing = [DiceThrowing() for i in range(times)]
    sns.histplot(data=total_throwing, bins=12)

# %%
ThrowDice(1000)
